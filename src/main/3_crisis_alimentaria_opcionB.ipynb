# %%
@ ElsaTH

# %% [markdown]
# ## OPCION B:

# %% [markdown]
# Importación de librerías:

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Abrir archivo en csv para poder limpiar datos:

# %%
df = pd.read_csv("FAO.csv",encoding="ISO-8859-1")  
df
# Out:
#       Area Abbreviation  Area Code         Area  Item Code  \
# 0                   AFG          2  Afghanistan       2511
# 1                   AFG          2  Afghanistan       2805
# 2                   AFG          2  Afghanistan       2513
# 3                   AFG          2  Afghanistan       2513
# 4                   AFG          2  Afghanistan       2514
# ...                 ...        ...          ...        ...
# 21472               ZWE        181     Zimbabwe       2948
# 21473               ZWE        181     Zimbabwe       2960
# 21474               ZWE        181     Zimbabwe       2960
# 21475               ZWE        181     Zimbabwe       2961
# 21476               ZWE        181     Zimbabwe       2928
#
#                            Item  Element Code Element         Unit  latitude  \
# 0            Wheat and products          5142    Food  1000 tonnes     33.94
# 1      Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# ...

# %%
df = df.loc[:,['Area', 'Item', 'Element', 'Unit', 'latitude', 'longitude', 'Y1961',
       'Y1962', 'Y1963', 'Y1964', 'Y1965', 'Y1966', 'Y1967', 'Y1968', 'Y1969',
       'Y1970', 'Y1971', 'Y1972', 'Y1973', 'Y1974', 'Y1975', 'Y1976', 'Y1977',
       'Y1978', 'Y1979', 'Y1980', 'Y1981', 'Y1982', 'Y1983', 'Y1984', 'Y1985',
       'Y1986', 'Y1987', 'Y1988', 'Y1989', 'Y1990', 'Y1991', 'Y1992', 'Y1993',
       'Y1994', 'Y1995', 'Y1996', 'Y1997', 'Y1998', 'Y1999', 'Y2000', 'Y2001',
       'Y2002', 'Y2003', 'Y2004', 'Y2005', 'Y2006', 'Y2007', 'Y2008', 'Y2009',
       'Y2010', 'Y2011', 'Y2012', 'Y2013']]

# %%
year = df.groupby("Area")['Y1961',
       'Y1962', 'Y1963', 'Y1964', 'Y1965', 'Y1966', 'Y1967', 'Y1968', 'Y1969',
       'Y1970', 'Y1971', 'Y1972', 'Y1973', 'Y1974', 'Y1975', 'Y1976', 'Y1977',
       'Y1978', 'Y1979', 'Y1980', 'Y1981', 'Y1982', 'Y1983', 'Y1984', 'Y1985',
       'Y1986', 'Y1987', 'Y1988', 'Y1989', 'Y1990', 'Y1991', 'Y1992', 'Y1993',
       'Y1994', 'Y1995', 'Y1996', 'Y1997', 'Y1998', 'Y1999', 'Y2000', 'Y2001',
       'Y2002', 'Y2003', 'Y2004', 'Y2005', 'Y2006', 'Y2007', 'Y2008', 'Y2009',
       'Y2010', 'Y2011', 'Y2012', 'Y2013'].sum()

# %%
year
# Out:
#                                       Y1961    Y1962    Y1963    Y1964  \
# Area
# Afghanistan                          9481.0   9414.0   9194.0  10170.0
# Albania                              1706.0   1749.0   1767.0   1889.0
# Algeria                              7488.0   7235.0   6861.0   7255.0
# Angola                               4834.0   4775.0   5240.0   5286.0
# Antigua and Barbuda                    92.0     94.0    105.0     95.0
# ...                                     ...      ...      ...      ...
# Venezuela (Bolivarian Republic of)   9523.0   9369.0   9788.0  10539.0
# Viet Nam                            23856.0  25220.0  26053.0  26377.0
# Yemen                                2982.0   3038.0   3147.0   3224.0
# Zambia                               2976.0   3057.0   3069.0   3121.0
# Zimbabwe                             3260.0   3503.0   3479.0   3738.0
#
#                                       Y1965    Y1966    Y1967    Y1968  \
# Area
# ...

# %%
year_spain = year.loc["Spain",:]
year_spain
# Out:
# Y1961     57983.0
# Y1962     58728.0
# Y1963     64092.0
# Y1964     63547.0
# Y1965     64796.0
# Y1966     70248.0
# Y1967     71315.0
# Y1968     74617.0
# Y1969     76067.0
# Y1970     78177.0
# Y1971     83404.0
# Y1972     85289.0
# Y1973     90955.0
# Y1974     97978.0
# Y1975     96302.0
# Y1976     92870.0
# Y1977     94513.0
# Y1978     98947.0
# Y1979    103518.0
# Y1980    106473.0
# Y1981    103272.0
# Y1982    105492.0
# Y1983    108171.0
# Y1984    113349.0
# Y1985    112503.0
# Y1986    108995.0
# Y1987    114346.0
# Y1988    114625.0
# Y1989    117972.0
# Y1990    120074.0
# Y1991    120149.0
# Y1992    117991.0
# Y1993    117297.0
# Y1994    116546.0
# Y1995    110088.0
# Y1996    120240.0
# Y1997    126645.0
# Y1998    130147.0
# Y1999    131408.0
# Y2000    133017.0
# Y2001    131812.0
# Y2002    135708.0
# Y2003    142802.0
# Y2004    142711.0
# Y2005    134618.0
# Y2006    138483.0
# Y2007    144947.0
# Y2008    141519.0
# Y2009    136073.0
# Y2010    133940.0
# ...

# %%
year_spain_10 = year.loc["Spain",['Y2003', 'Y2004','Y2005','Y2006','Y2007', 'Y2008','Y2009','Y2010','Y2011', 'Y2012','Y2013']]
year_spain_10
# Out:
# Y2003    142802.0
# Y2004    142711.0
# Y2005    134618.0
# Y2006    138483.0
# Y2007    144947.0
# Y2008    141519.0
# Y2009    136073.0
# Y2010    133940.0
# Y2011    133445.0
# Y2012    127967.0
# Y2013    137594.0
# Name: Spain, dtype: float64

# %% [markdown]
# Debido a la inmensidad de datos que conlleva mi dataset, he reducido los datos para poder representar la gráfica pedida. Para ello me centro cinco años antes de la crisis y 5 años después. Es decir, limito los datos a España desde 2003 hasta 2013.

# %% [markdown]
# * Realizo el histograma del dataset con bins 5

# %%
plt.figure(figsize=(20, 10))

year_spain_10.plot(kind="hist",label='Producción por años: desde 2007 a 2013',color="#E2B553", bins=5)

plt.legend(title="Producción toneladas",loc='top_left',edgecolor="#5A5034",facecolor="#76D7C4",framealpha=0.5, fontsize=14)
plt.suptitle('PRODUCCIÓN EN ESPAÑA', size=25, color="#5A5034")
plt.xlabel("Cantidad de materia prima", size=20, color="#5A5034")
plt.ylabel("Producción", size=20, color="#5A5034")
plt.xticks(rotation=0,FontSize=12,color="#5A5034")
plt.yticks(rotation=0,FontSize=12,color="#5A5034")

plt.savefig('Producción_España_bins5.png')
plt.show()

# %% [markdown]
# * Matriz de correlación

# %% [markdown]
# Para representar la matriz de correlación voy a tomar como referencia de mi dataset sólo España, ya que incluir a todos los paises hace demasiado estensa. Me centraré como en el apartado anterios desde el año 2003 hasta 2013.

# %%
df.set_index("Area", inplace=True)
df = df.loc["Spain",['Y2003', 'Y2004','Y2005','Y2006','Y2007', 'Y2008','Y2009','Y2010','Y2011', 'Y2012','Y2013']]

# %%
plt.figure(figsize=(20,10))
c = df.corr()
sns.heatmap(c, cmap="BrBG",annot=True)
c
# Out:
#           Y2003     Y2004     Y2005     Y2006     Y2007     Y2008     Y2009  \
# Y2003  1.000000  0.989194  0.972648  0.984650  0.990092  0.987860  0.978064
# Y2004  0.989194  1.000000  0.992748  0.993706  0.996085  0.994483  0.988648
# Y2005  0.972648  0.992748  1.000000  0.995958  0.990480  0.992659  0.993283
# Y2006  0.984650  0.993706  0.995958  1.000000  0.995403  0.997626  0.994578
# Y2007  0.990092  0.996085  0.990480  0.995403  1.000000  0.998635  0.993359
# Y2008  0.987860  0.994483  0.992659  0.997626  0.998635  1.000000  0.995640
# Y2009  0.978064  0.988648  0.993283  0.994578  0.993359  0.995640  1.000000
# Y2010  0.977693  0.987984  0.992872  0.995084  0.992798  0.995786  0.999221
# Y2011  0.976891  0.988124  0.992237  0.994881  0.993344  0.995738  0.997309
# Y2012  0.958309  0.981364  0.992065  0.988057  0.983835  0.986889  0.992771
# Y2013  0.971751  0.985702  0.988147  0.990841  0.992631  0.993709  0.991692
#
#           Y2010     Y2011     Y2012     Y2013
# ...

# %% [markdown]
# Otra forma de realizar la matriz de correlación utilizando una función:

# %%
def plot_corr(df,size=10):
    '''Function plots a graphical correlation matrix for each pair of columns in the dataframe.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot'''

    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns)
    plt.yticks(range(len(corr.columns)), corr.columns)
plot_corr(df)

# %% [markdown]
# El mapa de color es una forma visual muy útil para para conocer las variables y sus relaciones. A primera vista  llama mucho la atención que los años elegidos tienen una correlación que roza el 1. Parece haber una correlación significativa; en realidad es tan fuerte que podría indicar multicolinealidad, es decir, que básicamente ofrecen la misma información.

# %% [markdown]
# * Usar las funciones de Matplotlib par mostrar todos los gráficos. No con pandas directamente.

# %% [markdown]
# Este apartado ya está realizado en la opcion C, debido que sólo utilizo pandas para la limpieza de datos.
# Todas las gráficas están realizadas con la libreria de matplotlib.
